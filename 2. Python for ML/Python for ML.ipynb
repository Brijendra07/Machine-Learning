# %% [markdown]
# # Reading csv and excel files

# %%
# importing pandas library
import pandas as pd

# %%
# Reading csv file
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/2. Python for ML/data.csv')

# %%
df.head() # first five rows
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
# Read excel file
df1 = pd.read_excel('/content/drive/MyDrive/Machine Learning/2. Python for ML/data.xlsx')

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# # Dataframe and Basic operations

# %%
import pandas as pd

# %%
# Reading csv file
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/2. Python for ML/data2.csv')

# %%
# Dimension
df.shape
# Out:
# (699, 11)

# %%
# first 5 rows
df.head()
# Out:
#         ID  Clump_Thickness  ...  Mitoses  Cancer_Type
# 0  1000025                5  ...        1            2
# 1  1002945                5  ...        1            2
# 2  1015425                3  ...        1            2
# 3  1016277                6  ...        1            2
# 4  1017023                4  ...        1            2
#
# [5 rows x 11 columns]

# %%
# bottom 5 rows
df.tail()
# Out:
#          ID  Clump_Thickness  ...  Mitoses  Cancer_Type
# 694  776715                3  ...        1            2
# 695  841769                2  ...        1            2
# 696  888820                5  ...        2            4
# 697  897471                4  ...        1            4
# 698  897471                4  ...        1            4
#
# [5 rows x 11 columns]

# %%
# all column names
df.columns
# Out:
# Index(['ID', 'Clump_Thickness', 'Cell_Size_Uniformity',
#        'Cell_Shape_Uniformity', 'Marginal_Adhesion',
#        'Single_Epithelial_Cell_Size', 'Bare_Nuclei', 'Bland_Chromatin',
#        'Normal_Nucleoli', 'Mitoses', 'Cancer_Type'],
#       dtype='object')

# %%
# single column
df['Bare_Nuclei']
# Out:
# 0       1
# 1      10
# 2       2
# 3       4
# 4       1
#        ..
# 694     2
# 695     1
# 696     3
# 697     4
# 698     5
# Name: Bare_Nuclei, Length: 699, dtype: object

# %%
# multiple column
df[['Bare_Nuclei','Cancer_Type']]
# Out:
#     Bare_Nuclei  Cancer_Type
# 0             1            2
# 1            10            2
# 2             2            2
# 3             4            2
# 4             1            2
# ..          ...          ...
# 694           2            2
# 695           1            2
# 696           3            4
# 697           4            4
# 698           5            4
#
# [699 rows x 2 columns]

# %% [markdown]
# # Indexing in DataFrame

# %%
df.iloc[:5] # first 5 rows
# Out:
#         ID  Clump_Thickness  ...  Mitoses  Cancer_Type
# 0  1000025                5  ...        1            2
# 1  1002945                5  ...        1            2
# 2  1015425                3  ...        1            2
# 3  1016277                6  ...        1            2
# 4  1017023                4  ...        1            2
#
# [5 rows x 11 columns]

# %%
df.iloc[:,:2] # first 2 column
# Out:
#           ID  Clump_Thickness
# 0    1000025                5
# 1    1002945                5
# 2    1015425                3
# 3    1016277                6
# 4    1017023                4
# ..       ...              ...
# 694   776715                3
# 695   841769                2
# 696   888820                5
# 697   897471                4
# 698   897471                4
#
# [699 rows x 2 columns]

# %%
df[df['Cancer_Type'] == 2] # Condition
# Out:
#           ID  Clump_Thickness  ...  Mitoses  Cancer_Type
# 0    1000025                5  ...        1            2
# 1    1002945                5  ...        1            2
# 2    1015425                3  ...        1            2
# 3    1016277                6  ...        1            2
# 4    1017023                4  ...        1            2
# ..       ...              ...  ...      ...          ...
# 690   654546                1  ...        1            2
# 692   714039                3  ...        1            2
# 693   763235                3  ...        2            2
# 694   776715                3  ...        1            2
# 695   841769                2  ...        1            2
#
# [458 rows x 11 columns]
